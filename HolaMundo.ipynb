# %% [markdown]
# <a href="https://colab.research.google.com/github/Angel353/Hola_Mundo/blob/main/HolaMundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importamos las librerias: numpy y matplotlib
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Marca
# Alt + Enter

# %%
#Definimos 2 arreglos de dimensión 100
ys = 200 + np.random.randn(100)
x = np.arange (0,100,1)

# %%
# Graficamos los arreglos en un plano 2D
plt.plot(x, ys, "-")
plt.fill_between(x, ys, 195, where =(ys > 195), facecolor = "blue", alpha = 1)

#Agregamos título a la gráfica
plt.title("Sample Visualization")
plt.xlabel("Eje de las x", size = 16,)
plt.ylabel("Eje de las y", size = 16,)
plt.show()
